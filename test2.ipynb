# %%
import os
import numpy as np
import pandas as pd
import cv2
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# Paths to dataset
# Paths to dataset
base_dir = r"D:\blindness detection\aptos2019-blindness-detection"  # Use raw string
train_csv_path = os.path.join(base_dir, "train.csv")
train_images_path = os.path.join(base_dir, "train_images")

# Load the CSV file
df = pd.read_csv(train_csv_path)

# Map diagnosis to categorical values
df['diagnosis'] = df['diagnosis'].astype(int)
class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']

# %%
# import os
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from tensorflow.keras.utils import to_categorical
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
# from tqdm import tqdm
# import cv2

# # Paths to dataset
# base_dir = "D:/blindness detection/aptos2019-blindness-detection"  # Replace with your dataset folder path
# train_csv_path = os.path.join(base_dir, "train.csv")
# train_images_path = os.path.join(base_dir, "train_images")

# # Load the CSV file
# df = pd.read_csv(train_csv_path)

# # Map diagnosis to categorical values
# df['diagnosis'] = df['diagnosis'].astype(int)
# class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']

# # Function to preprocess images
# def preprocess_images(df, image_dir, img_size=(224, 224)):
#     images = []
#     labels = []

#     for _, row in tqdm(df.iterrows(), total=len(df), desc="Processing images"):
#         img_path = os.path.join(image_dir, row['id_code'] + ".png")
#         if os.path.exists(img_path):
#             # Load image
#             img = cv2.imread(img_path)
#             img = cv2.resize(img, img_size)  # Resize to 224x224
#             img = img / 255.0  # Normalize to [0, 1]

#             images.append(img)
#             labels.append(row['diagnosis'])
#         else:
#             print(f"Image not found: {img_path}")

#     images = np.array(images)
#     labels = np.array(labels)
#     return images, labels

# # Preprocess data
# images, labels = preprocess_images(df, train_images_path)

# # Convert labels to one-hot encoding
# labels = to_categorical(labels, num_classes=5)

# # Train-test split
# X_train, X_val, y_train, y_val = train_test_split(images, labels, test_size=0.2, random_state=42)

# print(f"Training data shape: {X_train.shape}")
# print(f"Validation data shape: {X_val.shape}")

# # CNN Model Definition
# cnn_model = Sequential([
#     Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
#     MaxPooling2D((2, 2)),
#     Conv2D(64, (3, 3), activation='relu'),
#     MaxPooling2D((2, 2)),
#     Flatten(),
#     Dense(128, activation='relu'),
#     Dense(5, activation='softmax')  # Output layer with 5 classes
# ])

# # Compile the CNN model
# cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# # Train the CNN model
# history = cnn_model.fit(X_train, y_train, epochs=10, validation_data=(X_val, y_val), batch_size=32)

# # Save the model
# model_path = os.path.join(base_dir, "cnn_model.h5")
# cnn_model.save(model_path)
# print(f"Model saved to {model_path}")


# import os   #main
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from tensorflow.keras.utils import to_categorical
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
# from tqdm import tqdm
# import cv2
# import matplotlib.pyplot as plt  


# base_dir = "D:/blindness detection/aptos2019-blindness-detection"  
# train_csv_path = os.path.join(base_dir, "train.csv")
# train_images_path = os.path.join(base_dir, "train_images")


# df = pd.read_csv(train_csv_path)

# df['diagnosis'] = df['diagnosis'].astype(int)
# class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']


# def preprocess_images(df, image_dir, img_size=(224, 224)):
#     images = []
#     labels = []

#     for _, row in tqdm(df.iterrows(), total=len(df), desc="Processing images"):
#         img_path = os.path.join(image_dir, row['id_code'] + ".png")
#         if os.path.exists(img_path):
          
#             img = cv2.imread(img_path)
#             img = cv2.resize(img, img_size)  
#             img = img / 255.0  

#             images.append(img)
#             labels.append(row['diagnosis'])
#         else:
#             print(f"Image not found: {img_path}")

#     images = np.array(images)
#     labels = np.array(labels)
#     return images, labels


# images, labels = preprocess_images(df, train_images_path)

# labels = to_categorical(labels, num_classes=5)

# X_train, X_val, y_train, y_val = train_test_split(images, labels, test_size=0.2, random_state=42)

# print(f"Training data shape: {X_train.shape}")
# print(f"Validation data shape: {X_val.shape}")


# cnn_model = Sequential([
#     Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
#     MaxPooling2D((2, 2)),
#     Conv2D(64, (3, 3), activation='relu'),
#     MaxPooling2D((2, 2)),
#     Flatten(),
#     Dense(128, activation='relu'),
#     Dense(5, activation='softmax')  
# ])


# cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


# history = cnn_model.fit(X_train, y_train, epochs=10, validation_data=(X_val, y_val), batch_size=32)


# model_path = os.path.join(base_dir, "cnn_model.h5")
# cnn_model.save(model_path)
# print(f"Model saved to {model_path}")

# def plot_accuracy_graph(history):
    
#     plt.figure(figsize=(10, 6))
#     plt.plot(history.history['accuracy'], label='Training Accuracy')
#     plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
#     plt.title('Training and Validation Accuracy')
#     plt.xlabel('Epochs')
#     plt.ylabel('Accuracy')
#     plt.legend(loc='best')
#     plt.grid(True)

   
#     plt.show()


# plot_accuracy_graph(history)


# #resnet(reminder)


import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.optimizers import Adam
from tqdm import tqdm
import cv2
import matplotlib.pyplot as plt  


base_dir = "D:/blindness detection/aptos2019-blindness-detection"  
train_csv_path = os.path.join(base_dir, "train.csv")
train_images_path = os.path.join(base_dir, "train_images")


df = pd.read_csv(train_csv_path)

df['diagnosis'] = df['diagnosis'].astype(int)
class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']


def preprocess_images(df, image_dir, img_size=(224, 224)):
    images = []
    labels = []

    for _, row in tqdm(df.iterrows(), total=len(df), desc="Processing images"):
        img_path = os.path.join(image_dir, row['id_code'] + ".png")
        if os.path.exists(img_path):
            img = cv2.imread(img_path)
            img = cv2.resize(img, img_size)
            img = preprocess_input(img)  # Preprocess for ResNet
            images.append(img)
            labels.append(row['diagnosis'])
        else:
            print(f"Image not found: {img_path}")

    images = np.array(images)
    labels = np.array(labels)
    return images, labels


images, labels = preprocess_images(df, train_images_path)

labels = to_categorical(labels, num_classes=5)

X_train, X_val, y_train, y_val = train_test_split(images, labels, test_size=0.2, random_state=42)

print(f"Training data shape: {X_train.shape}")
print(f"Validation data shape: {X_val.shape}")



input_shape = (224, 224, 3)
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)


for layer in base_model.layers:
    layer.trainable = False


x = base_model.output
x = GlobalAveragePooling2D()(x)  
x = Dense(128, activation='relu')(x)  
x = Dense(5, activation='softmax')(x)  

# Create the model
model = Model(inputs=base_model.input, outputs=x)


model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])


history = model.fit(X_train, y_train, epochs=10, validation_data=(X_val, y_val), batch_size=32)


model_path = os.path.join(base_dir, "resnet_model.h5")
model.save(model_path)
print(f"Model saved to {model_path}")


def plot_accuracy_graph(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()


plot_accuracy_graph(history)
# Out:
# Processing images: 100%|██████████| 3662/3662 [03:08<00:00, 19.39it/s]
# Training data shape: (2929, 224, 224, 3)
# Validation data shape: (733, 224, 224, 3)
# Epoch 1/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 156s 2s/step - accuracy: 0.6696 - loss: 0.9590 - val_accuracy: 0.7531 - val_loss: 0.7250
# Epoch 2/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 145s 2s/step - accuracy: 0.7913 - loss: 0.5884 - val_accuracy: 0.7749 - val_loss: 0.6180
# Epoch 3/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.8130 - loss: 0.5088 - val_accuracy: 0.7804 - val_loss: 0.6115
# Epoch 4/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 147s 2s/step - accuracy: 0.8458 - loss: 0.4386 - val_accuracy: 0.8090 - val_loss: 0.5450
# Epoch 5/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.8519 - loss: 0.4217 - val_accuracy: 0.7667 - val_loss: 0.5978
# Epoch 6/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 145s 2s/step - accuracy: 0.8531 - loss: 0.3982 - val_accuracy: 0.8035 - val_loss: 0.5469
# Epoch 7/10
# ...

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %%
import tensorflow as tf


gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"TensorFlow is using the GPU: {gpus}")
else:
    print("No GPU detected. TensorFlow is using the CPU.")
# Out:
# No GPU detected. TensorFlow is using the CPU.

# %%
import cv2
import numpy as np


image_path = 'D:/blindness detection/aptos2019-blindness-detection/Moderate/0ac436400db4.png'  


img = cv2.imread(image_path)


if img is None:
    print("Error: Unable to load image. Please check the image path.")
else:
    print("Image loaded successfully!")

    img = cv2.resize(img, (224, 224))  
    img = img / 255.0  
    img = np.expand_dims(img, axis=0)  

    cnn_model = tf.keras.models.load_model('D:/blindness detection/aptos2019-blindness-detection/cnn_model.h5')

  
    prediction = cnn_model.predict(img)
    predicted_class = np.argmax(prediction)
    
    
    class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']
    print(f"Predicted Class: {class_names[predicted_class]}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Image loaded successfully!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Predicted Class: Moderate

# %%
# import tkinter as tk
# from tkinter import filedialog, messagebox
# from PIL import Image, ImageTk
# import numpy as np
# import cv2
# import tensorflow as tf
# import threading  


# model_path = 'D:/blindness detection/aptos2019-blindness-detection/cnn_model.h5'  
# cnn_model = tf.keras.models.load_model(model_path)


# class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']

# def preprocess_image(image_path):
   
#     img = cv2.imread(image_path)
#     if img is None:
#         messagebox.showerror("Error", "Error loading image!")
#         return None
#     img = cv2.resize(img, (224, 224))  
#     img = img / 255.0  
#     img = np.expand_dims(img, axis=0)  
#     return img

# def predict_image():
    
#     file_path = filedialog.askopenfilename(title="Select an Image", filetypes=[("Image files", "*.png;*.jpg;*.jpeg")])
    
#     if file_path:
       
#         threading.Thread(target=run_prediction, args=(file_path,)).start()

# def run_prediction(image_path):
   
#     img = preprocess_image(image_path)
    
#     if img is not None:
       
#         prediction = cnn_model.predict(img)
#         predicted_class = class_names[np.argmax(prediction)]  
        
       
#         messagebox.showinfo("Prediction Result", f"The image is classified as: {predicted_class}")
        
    
#         display_image(image_path)

# def display_image(image_path):
    
#     img = Image.open(image_path)
#     img = img.resize((300, 300))  
#     img = ImageTk.PhotoImage(img)
    
   
#     panel = tk.Label(window, image=img)
#     panel.image = img  
#     panel.grid(row=1, column=0, columnspan=2)


# window = tk.Tk()
# window.title("Blindness Detection GUI")


# predict_button = tk.Button(window, text="Load and Predict Image", command=predict_image)
# predict_button.grid(row=0, column=0, padx=10, pady=10)


# window.mainloop()


# import tkinter as tk
# from tkinter import filedialog, messagebox
# from PIL import Image, ImageTk
# import numpy as np
# import cv2
# import tensorflow as tf
# import threading

# # Load the pre-trained model
# model_path = 'D:/blindness detection/aptos2019-blindness-detection/cnn_model.h5'
# cnn_model = tf.keras.models.load_model(model_path)

# # Class names for the predictions
# class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']

# def preprocess_image(image_path):
#     """Preprocess the image for prediction"""
#     img = cv2.imread(image_path)
#     if img is None:
#         messagebox.showerror("Error", "Error loading image!")
#         return None
#     img = cv2.resize(img, (224, 224))  # Resize image to fit model input
#     img = img / 255.0  # Normalize the image
#     img = np.expand_dims(img, axis=0)  # Add batch dimension
#     return img

# def predict_image():
#     """Open file dialog and run the prediction in a separate thread"""
#     file_path = filedialog.askopenfilename(title="Select an Image", filetypes=[("Image files", "*.png;*.jpg;*.jpeg")])
#     if file_path:
#         threading.Thread(target=run_prediction, args=(file_path,)).start()

# def run_prediction(image_path):
#     """Run the model prediction on the image"""
#     img = preprocess_image(image_path)
#     if img is not None:
#         prediction = cnn_model.predict(img)
#         predicted_class = class_names[np.argmax(prediction)]  # Get predicted class
#         messagebox.showinfo("Prediction Result", f"The image is classified as: {predicted_class}")
#         display_image(image_path)

# def display_image(image_path):
#     """Display the selected image in the GUI"""
#     img = Image.open(image_path)
#     img = img.resize((300, 300))  # Resize image to fit the window
#     img = ImageTk.PhotoImage(img)

#     # Clear previous image (if any) and display the new image
#     for widget in window.grid_slaves():
#         if int(widget.grid_info()["row"]) == 1:
#             widget.grid_forget()

#     panel = tk.Label(window, image=img)
#     panel.image = img  # Keep a reference to avoid garbage collection
#     panel.grid(row=1, column=0, columnspan=2, padx=20, pady=20)

# # Initialize the Tkinter window
# window = tk.Tk()
# window.title("Blindness Detection GUI")
# window.geometry("800x600")  # Set a fixed window size
# window.state("zoomed")  # Make the window full screen
# window.configure(bg="#f0f0f0")  # Set background color

# # Styling for buttons and labels
# button_style = {'font': ('Helvetica', 14), 'bg': '#4CAF50', 'fg': 'white', 'width': 20, 'height': 2, 'relief': 'flat'}
# label_style = {'font': ('Helvetica', 16), 'bg': '#f0f0f0', 'fg': '#333333'}

# # Create and place widgets
# predict_button = tk.Button(window, text="Load and Predict Image", command=predict_image, **button_style)
# predict_button.grid(row=0, column=0, padx=10, pady=10, sticky="ew")

# # Add a label for instructions
# instructions_label = tk.Label(window, text="Please load an image for blindness detection", **label_style)
# instructions_label.grid(row=0, column=1, padx=10, pady=10, sticky="ew")

# # Run the Tkinter event loop
# window.mainloop()

# import tkinter as tk
# from tkinter import filedialog, messagebox
# from PIL import Image, ImageTk
# import numpy as np
# import cv2
# import tensorflow as tf
# import threading

# # Load the pre-trained model
# model_path = 'D:/blindness detection/aptos2019-blindness-detection/cnn_model.h5'
# cnn_model = tf.keras.models.load_model(model_path)

# # Class names for the predictions
# class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']

# def preprocess_image(image_path):
#     """Preprocess the image for prediction"""
#     img = cv2.imread(image_path)
#     if img is None:
#         messagebox.showerror("Error", "Error loading image!")
#         return None
#     img = cv2.resize(img, (224, 224))  # Resize image to fit model input
#     img = img / 255.0  # Normalize the image
#     img = np.expand_dims(img, axis=0)  # Add batch dimension
#     return img

# def predict_image():
#     """Open file dialog and run the prediction in a separate thread"""
#     file_path = filedialog.askopenfilename(title="Select an Image", filetypes=[("Image files", "*.png;*.jpg;*.jpeg")])
#     if file_path:
#         threading.Thread(target=run_prediction, args=(file_path,)).start()

# def run_prediction(image_path):
#     """Run the model prediction on the image"""
#     img = preprocess_image(image_path)
#     if img is not None:
#         prediction = cnn_model.predict(img)
#         predicted_class = class_names[np.argmax(prediction)]  # Get predicted class
#         messagebox.showinfo("Prediction Result", f"The image is classified as: {predicted_class}")
#         display_image(image_path)

# def display_image(image_path):
#     """Display the selected image in the GUI"""
#     img = Image.open(image_path)
#     img = img.resize((300, 300))  # Resize image to fit the window
#     img = ImageTk.PhotoImage(img)

#     # Clear previous image (if any) and display the new image
#     for widget in frame.grid_slaves():
#         if int(widget.grid_info()["row"]) == 2:
#             widget.grid_forget()

#     panel = tk.Label(frame, image=img)
#     panel.image = img  # Keep a reference to avoid garbage collection
#     panel.grid(row=2, column=0, columnspan=2, pady=(20, 10))

# # Initialize the Tkinter window
# window = tk.Tk()
# window.title("Blindness Detection GUI")
# window.state("zoomed")  # Make the window full screen
# window.configure(bg="#f0f0f0")  # Set background color

# # Styling for buttons and labels
# button_style = {'font': ('Helvetica', 14, 'bold'), 'bg': '#4CAF50', 'fg': 'white', 'width': 25, 'height': 2, 'relief': 'raised'}
# label_style = {'font': ('Helvetica', 16), 'bg': '#f0f0f0', 'fg': '#333333'}

# # Create a central frame
# frame = tk.Frame(window, bg="#f0f0f0")
# frame.place(relx=0.5, rely=0.5, anchor="center")  # Center the frame in the window

# # Add a label for instructions
# instructions_label = tk.Label(frame, text="Please load an image for blindness detection", **label_style)
# instructions_label.grid(row=0, column=0, columnspan=2, pady=(0, 20))

# # Add the prediction button
# predict_button = tk.Button(frame, text="Load and Predict Image", command=predict_image, **button_style)
# predict_button.grid(row=1, column=0, columnspan=2, pady=10)

# # Run the Tkinter event loop
# window.mainloop()

import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk
import numpy as np
import cv2
import tensorflow as tf
import threading

# Load the pre-trained model
model_path = 'D:/blindness detection/aptos2019-blindness-detection/cnn_model.h5'
cnn_model = tf.keras.models.load_model(model_path)

# Class names for the predictions
class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']

def preprocess_image(image_path):
    """Preprocess the image for prediction"""
    img = cv2.imread(image_path)
    if img is None:
        result_label.config(text="Error: Unable to load the image.", fg="red")
        return None
    img = cv2.resize(img, (224, 224))  # Resize image to fit model input
    img = img / 255.0  # Normalize the image
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

def predict_image():
    """Open file dialog and run the prediction in a separate thread"""
    file_path = filedialog.askopenfilename(title="Select an Image", filetypes=[("Image files", "*.png;*.jpg;*.jpeg")])
    if file_path:
        threading.Thread(target=run_prediction, args=(file_path,)).start()

def run_prediction(image_path):
    """Run the model prediction on the image and display the result in the GUI"""
    img = preprocess_image(image_path)
    if img is not None:
        prediction = cnn_model.predict(img)
        predicted_class = class_names[np.argmax(prediction)]  # Get predicted class
        
        # Display the predicted class in a label
        result_label.config(text=f"Prediction: {predicted_class}", fg="#4CAF50", font=('Helvetica', 16, 'bold'))
        
        display_image(image_path)

def display_image(image_path):
    """Display the selected image in the GUI"""
    img = Image.open(image_path)
    img = img.resize((300, 300))  # Resize image to fit the window
    img = ImageTk.PhotoImage(img)

    # Clear previous image (if any) and display the new image
    for widget in frame.grid_slaves():
        if int(widget.grid_info()["row"]) == 2:
            widget.grid_forget()

    panel = tk.Label(frame, image=img)
    panel.image = img  # Keep a reference to avoid garbage collection
    panel.grid(row=2, column=0, columnspan=2, pady=(20, 10))

# Initialize the Tkinter window
window = tk.Tk()
window.title("Blindness Detection GUI")
window.state("zoomed")  # Make the window full screen
window.configure(bg="#f0f0f0")  # Set background color

# Styling for buttons and labels
button_style = {'font': ('Helvetica', 14, 'bold'), 'bg': '#4CAF50', 'fg': 'white', 'width': 25, 'height': 2, 'relief': 'raised'}
label_style = {'font': ('Helvetica', 16), 'bg': '#f0f0f0', 'fg': '#333333'}

# Create a central frame
frame = tk.Frame(window, bg="#f0f0f0")
frame.place(relx=0.5, rely=0.5, anchor="center")  # Center the frame in the window

# Add a label for instructions
instructions_label = tk.Label(frame, text="Please load an image for blindness detection", **label_style)
instructions_label.grid(row=0, column=0, columnspan=2, pady=(0, 20))

# Add the prediction button
predict_button = tk.Button(frame, text="Load and Predict Image", command=predict_image, **button_style)
predict_button.grid(row=1, column=0, columnspan=2, pady=10)

# Add a label for displaying prediction results
result_label = tk.Label(frame, text="", bg="#f0f0f0", fg="#333333", font=('Helvetica', 16))
result_label.grid(row=3, column=0, columnspan=2, pady=(10, 20))

# Run the Tkinter event loop
window.mainloop()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
